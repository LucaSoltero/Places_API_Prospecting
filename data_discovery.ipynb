# %%
import pandas as pd
from api_key import file_path

pd.set_option('display.max_columns', None)
df = pd.read_csv(f'{file_path}/data/HVAC_Query/MeshSearch_Plumbers_NYC.csv')
print("Total Plumbing businesses Extracted from API: ", len(df["place_id"].unique()))

icp = df[df["user_ratings_total"] > 1000]

print("Total Plumbing businesses with over 1000 reviews", len(icp))

print(icp)
# Out:
# Total Plumbing businesses Extracted from API:  1315
# Total Plumbing businesses with over 1000 reviews 16
#                          place_id  \
# 34    ChIJSxtutsa3w4kRJnADQAWHoVw
# 57    ChIJi_nBEeBNwokRKBER-LKNRgc
# 65    ChIJFdn88cVNwokRYPcGrv_KDUo
# 106   ChIJsVh4Iq1bwokR2e0XxzaZNbw
# 167   ChIJAQAAAC1iwokRNAgXJwtO08Y
# 193   ChIJn_b0ZAB_wokR_cnBr22YbKA
# 297   ChIJrYGZSU-yw4kR0dASD6gk2ig
# 323   ChIJVVVVVSlXwokRvLqs3INBYh8
# 358   ChIJPxOk2dxmwokRUNHcq9jTsOM
# 501   ChIJDY7dQp-vw4kRjeXGr8fQrtI
# 546   ChIJ9_pr9VNawokR-4Eadp9GqKs
# 653   ChIJk3d6D_9YwokRFurrWHEK3L4
# 858   ChIJrYKxBkiLwokRvfrWXtWeOMs
# 895   ChIJ06-fOGCow4kRnjb-0rLcPG0
# 1065  ChIJ1-M5VfHywokRcpFm4F4gRM0
# 1160  ChIJbSw87lvwwokRV9bF5f12IK0
#
#                                                   name  \
# 34    First Choice Plumbing Heating & Air Conditioning
# 57                             RR Plumbing Roto-Rooter
# 65                     P.A.C. Plumbing, Heating, & A/C
# ...
